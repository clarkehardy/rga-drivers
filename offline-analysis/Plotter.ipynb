# %%
# %load_ext autoreload
# %autoreload 2

# %%
from offline_analysis import OfflineAnalysis
import matplotlib.pyplot as plt 
import numpy as np 
import pandas as pd 
from datetime import datetime, timedelta
import struct
import glob

plt.style.use('~/40style.mplstyle')

# %%
data_directory = '/Users/linsi/Documents/stanford/scrubbing/rga-drivers/offline-analysis/rgafiles/'

analysis = OfflineAnalysis(data_directory)
analysis.load_data()

# Get the extracted times, masses, and pressures
times = analysis.get_times()
masses = analysis.get_masses()

#print(f"Loaded times: {times}")
#print(f"Masses: {masses}")

# %%
# Plot the first scan, using the timestamp in the title
analysis.plot_scan_zoom(0,125,137)
# Out:
# /Users/linsi/Documents/stanford/scrubbing/rga-drivers/offline-analysis/offline_analysis.py:160: UserWarning: Attempt to set non-positive ylim on a log-scaled axis will be ignored.
#   ax.set_ylim([y_min * 0.9, y_max * 1.1])  # Add some padding for better visibility

# %%
analysis.plot_mass_evolution(18, smoothing=False)

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 6))

analysis.plot_mass_evolution_peakfound(18, ax=ax, window=2.2,threshold_ratio=1.5)

plt.show()

# 17:50 turn on CEM
#
# Out:
# Significant change during Control Run at 2024-09-12 17:54:16, pressure ratio: 1.96
# Significant change during Control Run at 2024-09-13 17:25:16, pressure ratio: 3.60
# Significant change during Xenon Run at 2024-09-18 09:30:09, pressure ratio: 0.51
# Significant change during Xenon Run at 2024-09-18 09:32:46, pressure ratio: 0.58
# Significant change during Xenon Run at 2024-09-18 09:43:13, pressure ratio: 6.11
# Significant change during Xenon Run at 2024-09-18 09:53:41, pressure ratio: 0.31
# Significant change during Xenon Run at 2024-09-18 14:25:30, pressure ratio: 0.43
# Significant change during Xenon Run at 2024-09-18 14:43:41, pressure ratio: 8.50
# Significant change during Xenon Run at 2024-09-18 15:35:37, pressure ratio: 6.74
# Significant change during Xenon Run at 2024-09-18 15:38:13, pressure ratio: 0.19
# Significant change during Xenon Run at 2024-09-18 17:40:00, pressure ratio: 3.00
# Significant change during Xenon Run at 2024-09-24 13:37:41, pressure ratio: 0.28

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 6))

analysis.plot_mass_evolution_peakfound(28, ax=ax, window=2.2)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 6))

analysis.plot_mass_evolution_peakfound(128, ax=ax, window=2.2)

plt.show()

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 6))

analysis.plot_mass_evolution_peakfound(32, ax=ax, window=2.2)

plt.show()

# %%
analysis.plot_mass_evolution_peakfound_relative(28, 32)
